# %% [markdown]
# ### Download Important technologies and tools

# %% [markdown]
# ### **SQL Data Warehouse Project**
# #### IMPORTANT! Links to Project Resources:
# - [Download All Project Files](https://www.datawithbaraa.com/sql-introduction/advanced-sql-project/)
# - [SQL Project Git Repo](https://github.com/Hazemx95/sql_datawarehouse/tree/hz_feature)
# - [Project Management & Steps (Notion)](https://www.datawithbaraa.com/sql-introduction/advanced-sql-project/)

# %% [markdown]
# ### Three Stages Layer to build our data warehouse use (Medllian Architecture)
# - **Bronz Layer**
# - **Sliver Layer**
# - **Gold Layer**
